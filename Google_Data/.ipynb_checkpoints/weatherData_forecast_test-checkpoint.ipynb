# %%
from google.cloud import bigquery
import pandas as pd
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]= r"C:\Users\arthu\OneDrive\Ambiente de Trabalho\Projects\Google Cloud Data\weather_forecast\keys.json"
client = bigquery.Client()

## SELECT * FROM `fh-bigquery.weather_gsod.stations` WHERE name ="CURITIBA" 
## SELECT * FROM `fh-bigquery.weather_gsod.__TABLES__` 


query = """
    SELECT state, name, lat, lon
    FROM fh-bigquery.weather_gsod.stations
    WHERE country='BZ' AND name='SAO PAULO'
    LIMIT 30
"""
df = pd.read_gbq(query, dialect='standard')
df
# Out:
#   state       name      lat      lon
# 0  None  SAO PAULO -23500.0 -46617.0

# %%
query = """
    SELECT *
    FROM `fh-bigquery.weather_gsod.stations` WHERE name ="SAO PAULO"
"""

df_location = pd.read_gbq(query)
df_location
# Out:
#      usaf   wban       name country fips state  call      lat      lon  elev  \
# 0  837810  99999  SAO PAULO      BZ   BR  None  None -23500.0 -46617.0  7920
#
#       begin       end
# 0  19730101  20100428

# %%
query = """
SELECT * FROM `fh-bigquery.weather_gsod.__TABLES__`
"""

df_tables = pd.read_gbq(query)
df_tables
# Out:
#      project_id    dataset_id           table_id  creation_time  \
# 0   fh-bigquery  weather_gsod                all  1567654542095
# 1   fh-bigquery  weather_gsod  all_20191114_copy  1573756683222
# 2   fh-bigquery  weather_gsod   all_geoclustered  1567810947385
# 3   fh-bigquery  weather_gsod           gsod1929  1422594813268
# 4   fh-bigquery  weather_gsod           gsod1930  1422594924816
# ..          ...           ...                ...            ...
# 88  fh-bigquery  weather_gsod           gsod2014  1422315236647
# 89  fh-bigquery  weather_gsod           gsod2015  1422319014154
# 90  fh-bigquery  weather_gsod           gsod2016  1452818743847
# 91  fh-bigquery  weather_gsod           stations  1422004083189
# 92  fh-bigquery  weather_gsod          stations2  1459814608701
#
#     last_modified_time  row_count   size_bytes  type
# 0        1598046001324  155852507  49765427093     1
# 1        1573756683222  152678184  48748387264     1
# 2        1597969776066  152236272  48607114661     1
# 3        1422594813268       2081       383935     1
# 4        1422594924816       7285      1342700     1
# ..                 ...        ...          ...   ...
# 88       1422320944529    4115582    769185623     1
# 89       1452834512034    4200939    784964925     1
# 90       1475641642506     153706     28756392     1
# 91       1422004083189      31700      2474640     1
# 92       1459814608701      29430      2558203     1
#
# [93 rows x 8 columns]

# %%
query = """
    SELECT *
    FROM `fh-bigquery.weather_gsod.all`
    WHERE name = 'SAO PAULO'
"""
    
df_temp = pd.read_gbq(query)
df_temp
# Out:
#           date   wban     stn  year  mo  da  temp  count_temp  dewp  \
# 0   1979-05-29  99999  837810  1979  05  29  67.1           4  56.8
# 1   1979-03-27  99999  837810  1979  03  27  62.2           4  56.3
# 2   1979-04-09  99999  837810  1979  04  09  60.8           4  56.3
# 3   1979-02-08  99999  837810  1979  02  08  77.4           4  66.2
# 4   1979-08-20  99999  837810  1979  08  20  59.0           4  56.8
# ..         ...    ...     ...   ...  ..  ..   ...         ...   ...
# 410 1979-02-22  99999  837810  1979  02  22  67.3           5  64.0
# 411 1979-09-01  99999  837810  1979  09  01  74.5           5  60.8
# 412 1979-04-28  99999  837810  1979  04  28  61.2           5  55.4
# 413 1979-06-01  99999  837810  1979  06  01  43.5           5  33.8
# 414 1978-12-11  99999  837810  1978  12  11  65.8           5  56.5
#
#      count_dewp  ...  country  state  call   lat     lon     elev     begin  \
# 0             4  ...       BR   None  None -23.5 -46.617  +0792.0  19730101
# 1             4  ...       BR   None  None -23.5 -46.617  +0792.0  19730101
# 2             4  ...       BR   None  None -23.5 -46.617  +0792.0  19730101
# 3             4  ...       BR   None  None -23.5 -46.617  +0792.0  19730101
# 4             4  ...       BR   None  None -23.5 -46.617  +0792.0  19730101
# ..          ...  ...      ...    ...   ...   ...     ...      ...       ...
# 410           5  ...       BR   None  None -23.5 -46.617  +0792.0  19730101
# 411           5  ...       BR   None  None -23.5 -46.617  +0792.0  19730101
# 412           5  ...       BR   None  None -23.5 -46.617  +0792.0  19730101
# 413           5  ...       BR   None  None -23.5 -46.617  +0792.0  19730101
# 414           5  ...       BR   None  None -23.5 -46.617  +0792.0  19730101
#
#           end             point_gis  fake_date
# 0    20100428  POINT(-46.617 -23.5) 2000-01-01
# 1    20100428  POINT(-46.617 -23.5) 2000-01-01
# 2    20100428  POINT(-46.617 -23.5) 2000-01-01
# 3    20100428  POINT(-46.617 -23.5) 2000-01-01
# 4    20100428  POINT(-46.617 -23.5) 2000-01-01
# ..        ...                   ...        ...
# 410  20100428  POINT(-46.617 -23.5) 2000-01-01
# 411  20100428  POINT(-46.617 -23.5) 2000-01-01
# 412  20100428  POINT(-46.617 -23.5) 2000-01-01
# 413  20100428  POINT(-46.617 -23.5) 2000-01-01
# 414  20100428  POINT(-46.617 -23.5) 2000-01-01
#
# [415 rows x 45 columns]

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt 
plt.style.use('fivethirtyeight')
df_temp.sort_index()
df_temp = df_temp.set_index(pd.DatetimeIndex(df_temp['date']))
df_temp.to_csv('temp.csv')

# %%
plt.figure(figsize=(12.2,5))
df_temp['temp'].plot()
plt.xlabel('Date')
plt.ylabel('Temp Value')
plt.show()

# %%
query = """
    SELECT column_name
    FROM fh-bigquery.weather_gsod.INFORMATION_SCHEMA.COLUMNS
    WHERE table_name = 'gsod2016'
"""

columns = pd.read_gbq(query)
columns
# Out:
#              column_name
# 0                    stn
# 1                   wban
# 2                   year
# 3                     mo
# 4                     da
# 5                   temp
# 6             count_temp
# 7                   dewp
# 8             count_dewp
# 9                    slp
# 10             count_slp
# 11                   stp
# 12             count_stp
# 13                 visib
# 14           count_visib
# 15                  wdsp
# 16            count_wdsp
# 17                 mxpsd
# 18                  gust
# 19                   max
# 20              flag_max
# 21                   min
# 22              flag_min
# 23                  prcp
# 24             flag_prcp
# 25                  sndp
# 26                   fog
# 27          rain_drizzle
# 28      snow_ice_pellets
# 29                  hail
# 30               thunder
# 31  tornado_funnel_cloud

# %%
query = """
    SELECT T.stn,T.year,T.mo,T.da,T.temp 
    FROM `fh-bigquery.weather_gsod.gsod*` T LEFT JOIN `fh-bigquery.weather_gsod.stations` L
    ON T.stn = L.usaf
    WHERE L.country = "BZ" AND  T._TABLE_SUFFIX BETWEEN '2015' AND '2016'
"""
    
df_temp2016 = pd.read_gbq(query)
df_temp2016
# Out:
#           stn  year  mo  da  temp
# 0      820220  2016  01  04  80.7
# 1      828240  2016  01  01  78.3
# 2      834600  2016  01  03  81.0
# 3      836490  2016  01  02  82.6
# 4      837460  2016  01  01  87.4
# ...       ...   ...  ..  ..   ...
# 41834  312600  2015  06  01  79.4
# 41835  312600  2015  06  08  78.1
# 41836  312600  2015  06  20  78.8
# 41837  312600  2015  06  30  78.4
# 41838  312600  2015  07  28  77.1
#
# [41839 rows x 5 columns]

# %%
df_temp2016.columns = ['stn','year','month','day','temp']
df_temp2016['date'] = pd.to_datetime(df_temp2016[['year', 'month', 'day']])
df_temp2016 = df_temp2016.set_index(df_temp2016['date'])
df_temp2016
# Out:
#                stn  year month day  temp       date
# date
# 2016-01-04  820220  2016    01  04  80.7 2016-01-04
# 2016-01-01  828240  2016    01  01  78.3 2016-01-01
# 2016-01-03  834600  2016    01  03  81.0 2016-01-03
# 2016-01-02  836490  2016    01  02  82.6 2016-01-02
# 2016-01-01  837460  2016    01  01  87.4 2016-01-01
# ...            ...   ...   ...  ..   ...        ...
# 2015-06-01  312600  2015    06  01  79.4 2015-06-01
# 2015-06-08  312600  2015    06  08  78.1 2015-06-08
# 2015-06-20  312600  2015    06  20  78.8 2015-06-20
# 2015-06-30  312600  2015    06  30  78.4 2015-06-30
# 2015-07-28  312600  2015    07  28  77.1 2015-07-28
#
# [41839 rows x 6 columns]

# %%
df_temp2016.to_csv('df.csv')

# %%
plt.figure(figsize=(12.2,5))
df_temp2016['temp'].plot()
plt.xlabel('Date')
plt.ylabel('Temp Value')
plt.show()

# %%
df_temp2016_daily = df_temp2016.groupby(df_temp2016.index).mean()

# %%
plt.figure(figsize=(12.2,5))
df_temp2016_daily['temp'].plot()
plt.xlabel('Date')
plt.ylabel('Temp Value')
plt.show()

# %%
df_month = df_temp2016.groupby(pd.Grouper(freq="M")).mean()
plt.figure(figsize=(12.2,5))
df_month['temp'].plot()
plt.xlabel('Date')
plt.ylabel('Temp Value')
plt.show()

# %%
df_temp2016_daily['Rolling 30 mean']=df_temp2016_daily['temp'].rolling(30).mean()
plt.figure(figsize=(12.2,5))
df_temp2016_daily['temp'].plot(color='red')
df_temp2016_daily['Rolling 30 mean'].plot(color='green')
plt.xlabel('Date')
plt.ylabel('Temp Value')
plt.show()
